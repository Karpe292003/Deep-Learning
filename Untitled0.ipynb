# %%
! pip install npy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement npy (from versions: none)
# ERROR: No matching distribution found for npy

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

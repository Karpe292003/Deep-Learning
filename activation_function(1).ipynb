# %%
import numpy as np

# %%
z=np.arange(-15,15.1,0.25)

# %%
z
# Out:
# array([-15.  , -14.75, -14.5 , -14.25, -14.  , -13.75, -13.5 , -13.25,
#        -13.  , -12.75, -12.5 , -12.25, -12.  , -11.75, -11.5 , -11.25,
#        -11.  , -10.75, -10.5 , -10.25, -10.  ,  -9.75,  -9.5 ,  -9.25,
#         -9.  ,  -8.75,  -8.5 ,  -8.25,  -8.  ,  -7.75,  -7.5 ,  -7.25,
#         -7.  ,  -6.75,  -6.5 ,  -6.25,  -6.  ,  -5.75,  -5.5 ,  -5.25,
#         -5.  ,  -4.75,  -4.5 ,  -4.25,  -4.  ,  -3.75,  -3.5 ,  -3.25,
#         -3.  ,  -2.75,  -2.5 ,  -2.25,  -2.  ,  -1.75,  -1.5 ,  -1.25,
#         -1.  ,  -0.75,  -0.5 ,  -0.25,   0.  ,   0.25,   0.5 ,   0.75,
#          1.  ,   1.25,   1.5 ,   1.75,   2.  ,   2.25,   2.5 ,   2.75,
#          3.  ,   3.25,   3.5 ,   3.75,   4.  ,   4.25,   4.5 ,   4.75,
#          5.  ,   5.25,   5.5 ,   5.75,   6.  ,   6.25,   6.5 ,   6.75,
#          7.  ,   7.25,   7.5 ,   7.75,   8.  ,   8.25,   8.5 ,   8.75,
#          9.  ,   9.25,   9.5 ,   9.75,  10.  ,  10.25,  10.5 ,  10.75,
#         11.  ,  11.25,  11.5 ,  11.75,  12.  ,  12.25,  12.5 ,  12.75,
#         13.  ,  13.25,  13.5 ,  13.75,  14.  ,  14.25,  14.5 ,  14.75,
#         15.  ])

# %%
y=z*1.5+5

# %%
y
# Out:
# array([-17.5  , -17.125, -16.75 , -16.375, -16.   , -15.625, -15.25 ,
#        -14.875, -14.5  , -14.125, -13.75 , -13.375, -13.   , -12.625,
#        -12.25 , -11.875, -11.5  , -11.125, -10.75 , -10.375, -10.   ,
#         -9.625,  -9.25 ,  -8.875,  -8.5  ,  -8.125,  -7.75 ,  -7.375,
#         -7.   ,  -6.625,  -6.25 ,  -5.875,  -5.5  ,  -5.125,  -4.75 ,
#         -4.375,  -4.   ,  -3.625,  -3.25 ,  -2.875,  -2.5  ,  -2.125,
#         -1.75 ,  -1.375,  -1.   ,  -0.625,  -0.25 ,   0.125,   0.5  ,
#          0.875,   1.25 ,   1.625,   2.   ,   2.375,   2.75 ,   3.125,
#          3.5  ,   3.875,   4.25 ,   4.625,   5.   ,   5.375,   5.75 ,
#          6.125,   6.5  ,   6.875,   7.25 ,   7.625,   8.   ,   8.375,
#          8.75 ,   9.125,   9.5  ,   9.875,  10.25 ,  10.625,  11.   ,
#         11.375,  11.75 ,  12.125,  12.5  ,  12.875,  13.25 ,  13.625,
#         14.   ,  14.375,  14.75 ,  15.125,  15.5  ,  15.875,  16.25 ,
#         16.625,  17.   ,  17.375,  17.75 ,  18.125,  18.5  ,  18.875,
#         19.25 ,  19.625,  20.   ,  20.375,  20.75 ,  21.125,  21.5  ,
#         21.875,  22.25 ,  22.625,  23.   ,  23.375,  23.75 ,  24.125,
#         24.5  ,  24.875,  25.25 ,  25.625,  26.   ,  26.375,  26.75 ,
#         27.125,  27.5  ])

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(z,y)

# %%
z=np.arange(-5,5.1,0.25)

# %%
def sigmoid(z):
  val = 1/(1+np.exp(-z))
  return val

# %%
y= sigmoid(z)

# %%
y
# Out:
# array([0.00669285, 0.00857749, 0.01098694, 0.01406363, 0.01798621,
#        0.02297737, 0.02931223, 0.03732689, 0.04742587, 0.06008665,
#        0.07585818, 0.09534946, 0.11920292, 0.1480472 , 0.18242552,
#        0.22270014, 0.26894142, 0.3208213 , 0.37754067, 0.4378235 ,
#        0.5       , 0.5621765 , 0.62245933, 0.6791787 , 0.73105858,
#        0.77729986, 0.81757448, 0.8519528 , 0.88079708, 0.90465054,
#        0.92414182, 0.93991335, 0.95257413, 0.96267311, 0.97068777,
#        0.97702263, 0.98201379, 0.98593637, 0.98901306, 0.99142251,
#        0.99330715])

# %%
plt.plot(z,y)

# %%
z=np.arange(-5,5.1,0.25)

# %%
def relu(z):
  if z>0:
    return z
  else:
      return 0

# %%
def softmax(z):
  val = np.exp(z)/sum(np.exp(z))
  return val

# %%
data = [56,33,5,6,78,21]

# %%
softmax(data)
# Out:
# array([2.78946809e-10, 2.86251858e-20, 1.97925988e-32, 5.38018616e-32,
#        1.00000000e+00, 1.75879220e-25])

# %%
sum(softmax(data))
# Out:
# 1.0

# %%
plt.plot(z,sigmoid(z),color='b',label='sigmoid')
plt.grid()
plt.legend()

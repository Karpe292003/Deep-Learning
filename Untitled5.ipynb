# %%
# !pip install torch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (1.12.1+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch) (4.1.1)

# %%
import torch

# %%
t=torch.tensor(4) 
print(t) 
print(t.dtype)
# Out:
# tensor(4)
# torch.int64

# %%
t1=torch.tensor([1,4,5])
print(t1)
print(t1.dtype)
# Out:
# tensor([1, 4, 5])
# torch.int64

# %%
# !pip install pillow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (7.1.2)

# %%
import numpy as np
import PIL

# %%
from PIL import Image
img=Image.open('/content/Shiv1.png')
print(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1366x768 at 0x7F056B71B810>

# %%
print(img.size)
# Out:
# (1366, 768)

# %%
from numpy import asarray
imgarr=asarray(img)
print(imgarr)

imgtensor=torch.from_numpy(imgarr)
# Out:
# [[[249 103   8]
#   [248 102   8]
#   [247 101   6]
#   ...
#   [  0   0   0]
#   [  0   0   0]
#   [  0   0   0]]
#
#  [[247 101   7]
#   [248 102   7]
#   [248 102   7]
#   ...
#   [  0   0   0]
#   [  0   0   0]
#   [  0   0   0]]
#
#  [[246 100   5]
#   [247 101   6]
#   [248 102   7]
#   ...
#   [  0   0   0]
#   [  0   0   0]
#   [  0   0   0]]
#
#  ...
#
#  [[ 92  74  48]
#   [ 92  74  47]
#   [ 92  73  47]
#   ...
#   [ 53   8   0]
#   [ 49   4   0]
#   [ 49   3   0]]
#
#  [[ 91  73  47]
#   [ 91  73  47]
#   [ 91  73  46]
#   ...
#   [ 53   8   0]
#   [ 49   4   0]
#   [ 49   3   0]]
#
#  [[ 91  72  46]
#   [ 91  73  46]
#   [ 90  72  46]
#   ...
#   [ 53   8   0]
#   [ 49   4   0]
#   [ 49   3   0]]]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ../torch/csrc/utils/tensor_numpy.cpp:172.)
#   """

# %%
print(imgtensor.dtype)
# Out:
# torch.uint8

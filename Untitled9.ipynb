# %%
pip install jupyterlab

# %%
jupyter-lab
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-638650491fd9> in <cell line: 1>()
# ----> 1 jupyter-lab
#
# NameError: name 'jupyter' is not defined

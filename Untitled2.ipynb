# %%
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
data = pd.read_excel('/content/Alumni Working in Japan.xlsx')
data
# Out:
#     Sr No        Student Name                    Company Name     Company Pkg  \
# 0       1    Mayuri Shankhpal            Honda Motor Co.Ltd.      40 LPA JPY
# 1       2         Akshay Hase                             TCS     42 LPA JPY
# 2       3      Mayur Shermale                  NTT Data Japan     38 LPA JPY
# 3       4  Pranjali Bandawane                   Tech Mahindra     38 LPA JPY
# 4       5     Saloni Naikwadi                         Fujitsu     48 LPA JPY
# 5       6      Mahesh Mandlik                         Fujitsu     48 LPA JPY
# 6       7      Rohit Buchkul                          Fujitsu     48 LPA JPY
# 7       8        Pradip Gawde                   OS Technology     55 LPA JPY
# 8       9         Tejus Powar                   OS Technology     55 LPA JPY
# 9      10        Prapti Bnote           TechnoPro Engineering  30.20 LPA JPY
# 10     11       Tushar Gopale                       TCS Japan     23 LPA JPY
# ...

# %%
data.head(3)
# Out:
#    Sr No      Student Name          Company Name  Company Pkg  \
# 0      1  Mayuri Shankhpal  Honda Motor Co.Ltd.   40 LPA JPY
# 1      2       Akshay Hase                   TCS  42 LPA JPY
# 2      3    Mayur Shermale        NTT Data Japan  38 LPA JPY
#
#                 Department  Year of passing Japanese Level completed  \
# 0  Mechanical Engineering              2018                       N2
# 1  Mechanical Engineering              2019                       N5
# 2  Electronics Engineering             2018                       N3
#
#    Contact No
# 0  9527265166
# 1  7057535717
# 2  9604676505

# %%
data.tail(2)
# Out:
#     Sr No   Student Name           Company Name     Company Pkg  \
# 18     19  Abhikesh Wale  TechnoPro Engineering  30.20 LPA JPY
# 19     20   Deepak Pawar                Infosys             NaN
#
#                  Department  Year of passing Japanese Level completed  \
# 18  Electronics Engineering             2017                       N2
# 19   Information Technology             2006                       N1
#
#     Contact No
# 18  9404801084
# 19  8035009055

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Sr No                     20 non-null     int64
#  1   Student Name              20 non-null     object
#  2   Company Name              20 non-null     object
#  3   Company Pkg               19 non-null     object
#  4   Department                20 non-null     object
#  5   Year of passing           20 non-null     int64
#  6   Japanese Level completed  20 non-null     object
#  7   Contact No                20 non-null     int64
# dtypes: int64(3), object(5)
# memory usage: 1.4+ KB

# %%
data.describe()
# Out:
#           Sr No  Year of passing    Contact No
# count  20.00000        20.000000  2.000000e+01
# mean   10.50000      2017.650000  8.692520e+09
# std     5.91608         2.870448  9.831440e+08
# min     1.00000      2006.000000  7.057536e+09
# 25%     5.75000      2017.750000  7.903090e+09
# 50%    10.50000      2018.000000  9.121718e+09
# 75%    15.25000      2019.000000  9.546618e+09
# max    20.00000      2020.000000  9.960876e+09

# %%
data.columns
# Out:
# Index(['Sr No', 'Student Name', 'Company Name', 'Company Pkg', 'Department',
#        'Year of passing', 'Japanese Level completed', 'Contact No'],
#       dtype='object')

# %%
data[['Student Name','Contact No']]
# Out:
#           Student Name  Contact No
# 0     Mayuri Shankhpal  9527265166
# 1          Akshay Hase  7057535717
# 2       Mayur Shermale  9604676505
# 3   Pranjali Bandawane  9657319552
# 4      Saloni Naikwadi  9156317467
# 5       Mahesh Mandlik  9130650434
# 6       Rohit Buchkul   7261995614
# 7         Pradip Gawde  8092685455
# 8          Tejus Powar  9689992173
# 9         Prapti Bnote  9768979605
# 10       Tushar Gopale  9168575665
# 11      Harshal Sakhre  8087301719
# 12         Baban Pawar  7387907986
# 13       Amit Khemnar   8888294310
# 14        Pritam Kadam  9112785793
# 15        Poonam Awari  7350095662
# 16       Pranita Getam  9960875562
# 17      Sneha Bhalerao  7507332642
# 18       Abhikesh Wale  9404801084
# 19        Deepak Pawar  8035009055

# %%
plt.scatter(Student Name,Contact No)
# Out:
#   File "<ipython-input-15-2293b26e2433>", line 1
#     plt.scatter(Student Name,Contact No)
#                            ^
# SyntaxError: invalid syntax
